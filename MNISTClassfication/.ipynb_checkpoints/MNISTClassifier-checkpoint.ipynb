# %%
import tensorflow as tf
import tensorflow.keras as keras

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mnist = keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()

# %%
plt.figure()
plt.imshow(x_train[1])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.xlabel(y_train[i])
plt.show()

# %%
model = keras.Sequential()

model.add(keras.layers.Flatten(input_shape = (28,28)))
model.add(keras.layers.Dense(128, activation = 'relu'))
model.add(keras.layers.Dense(10, activation = 'softmax'))

model.compile(optimizer = 'adam',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(x = x_train, y = y_train, epochs=2)
# Out:
# Epoch 1/2
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.2559 - acc: 0.9263
# Epoch 2/2
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.1152 - acc: 0.9666

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# 10000/10000 [==============================] - 1s 53us/sample - loss: 0.1005 - acc: 0.9694

# %%
model.predict(x_test[1].reshape((1,28,28)))
# Out:
# array([[6.6169275e-07, 1.7890582e-03, 9.8684233e-01, 1.1291038e-02,
#         6.1460469e-11, 6.5407869e-05, 4.2155605e-07, 3.8595052e-09,
#         1.1048646e-05, 7.4023003e-11]], dtype=float32)

# %%
plt.figure(figsize = (10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(x_test[i])
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(np.argmax(model.predict(x_test)[i]))
plt.show()

# %%
prediction = model.predict(x_test)
plt.figure(figsize = (10,10))
iplt = 0
for idx in range(len(prediction)):
    label = np.argmax(prediction[idx])
    if label != y_test[idx]:
        iplt += 1
        plt.subplot(5,5,iplt)
        plt.imshow(x_test[idx])
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(label)
        if iplt == 25:
            break
plt.show()
